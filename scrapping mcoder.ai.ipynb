# %%
import urllib.request
datos = urllib.request.urlopen("http://mcoder.ai").read().decode()

# %%
datos
# Out:
# '<!DOCTYPE html>\n<html  >\n<head>\n  <!-- Site made with Mobirise Website Builder v5.2.0, https://mobirise.com -->\n  <meta charset="UTF-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="generator" content="Mobirise v5.2.0, mobirise.com">\n  <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1">\n  <link rel="shortcut icon" href="assets/images/mcoder-original-parcial.png" type="image/x-icon">\n  <meta name="description" content="En Mcoder.ai México nos enfocamos en difundir, compartir conocimiento y capacitar a quien requiera fortalecer sus conocimientos tecnológicos.">\n  \n  \n  <title>Home</title>\n  <link rel="stylesheet" href="assets/web/assets/mobirise-icons/mobirise-icons.css">\n  <link rel="stylesheet" href="assets/simple-line-icons/simple-line-icons.css">\n  <link rel="stylesheet" href="assets/font-awesome/css/font-awesome.css">\n  <link rel="stylesheet" href="assets/web/assets/mobirise-icons2/mobirise2.css">\n  <link rel="stylesheet" href="assets/icons-mind/style.css">\n  <link rel="stylesheet" href="assets/bootstrap/css/bootstrap.min.css">\n  <link rel="stylesheet" href="assets/bootstrap/css/bootstrap-grid.min.css">\n  <link rel="stylesheet" href="assets/bootstrap/css/bootstrap-reboot.min.css">\n  <link rel="stylesheet" href="assets/tether/tether.min.css">\n  <link rel="stylesheet" href="assets/dropdown/css/style.css">\n  <link rel="stylesheet" href="assets/as-pie-progress/css/progress.min.css">\n  <link rel="stylesheet" href="assets/socicon/css/styles.css">\n  <link rel="stylesheet" href="assets/theme/css/style.css">\n  <link rel="stylesheet" href="assets/wowslider-init/style.css">\n  <link rel="preload" as="style" href="assets/mobirise/css/mbr-additional.css"><link rel="stylesheet" href="assets/mobirise/css/mbr-additional.css" type="text/css">\n  \n  \n  \n  \n<link rel="stylesheet" href = "assets/wowslider-init/boundary/style.css"></link></head>\n<body>\n\n<!-- Analytics -->\n\t    <!-- Global site tag (gtag.js) - Google Analytics -->\n    <script async src="https://www.googletagmanager.com/gtag/js?id=UA-153640399-1"></script>\n    <script>\n      window.dataLayer = window.dataLayer || [];\n      function gtag(){dataLayer.push(arguments);}\n      gtag(\'js\', new Date());\n\n      gtag(\'config\', \'UA-153640399-1\');\n    </script>\n<!-- /Analytics -->\n\n\n  \n  <section class="menu cid-rWNdkIOYEL" once="menu" id="menu2-0">\n\n    \n\n    <nav class="navbar navbar-expand beta-menu navbar-dropdown align-items-center navbar-fixed-top navbar-toggleable-sm">\n        <button class="navbar-toggler navbar-toggler-right" type="button" data-toggle="collapse" data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">\n            <div class="hamburger">\n                <span></span>\n                <span></span>\n                <span></span>\n                <span></span>\n            </div>\n        </button>\n        <div class="menu-logo">\n            <div class="navbar-brand">\n                <span class="navbar-logo">\n                    <a href="index.html">\n                        <img src="assets/images/mcoder-original-fondo-blanco.png" alt="Mcoder.ai" title=" Mcoder México - Artificial Intelligence" style="height: 3.8rem;">\n                    </a>\n                </span>\n                \n            </div>\n        </div>\n        <div class="collapse navbar-collapse" id="navbarSupportedContent">\n            <ul class="navbar-nav nav-dropdown" data-app-modern-menu="true"><li class="nav-item">\n                    <a class="nav-link link text-black display-4" href="index.html">\n                        Home</a>\n                </li>\n                <li class="nav-item">\n                    <a class="nav-link link text-black display-4" href="community.html">Nuestro equipo</a>\n                </li></ul>\n            <div class="navbar-buttons mbr-section-btn"><a class=" ...

# %%
import sys
# !{sys.executable} -m pip install beayutifulsoup4
# Out:
# ERROR: Could not find a version that satisfies the requirement beayutifulsoup4 (from versions: none)
# ERROR: No matching distribution found for beayutifulsoup4

# %%
from bs4 import BeautifulSoup
soup =  BeautifulSoup(datos)
tags = soup("a")
for tag in tags:
        print(tag.get("href"))
# Out:
# index.html
# index.html
# community.html
# https://bit.ly/3anY5xh
# http://wlab.org.mx
# https://fb.me/e/1C2LomY3K
# https://fb.me/e/1C2LomY3K
# http://wlab.org.mx
# http://wlab.org.mx
# https://www.facebook.com/McoderAI
# community.html
# http://mybitly.xyz/mcev0x0420w
# http://mybitly.xyz/mcev0x0320w
# http://mybitly.xyz/mcev0x0320w
# http://mybitly.xyz/mcev0x0420w
# #
# #
# #
# #
# #
# #
# #
# gallery.html
#
# #lb-
# #lb-
#
# #lb-
# #lb-
#
# #lb-
# #lb-
#
# #lb-
# #lb-
#
# #lb-
# #lb-
# http://wlab.org.mx
# None
# None
# index.html
# index.html
# https://www.facebook.com/McoderAI
# https://www.instagram.com/McoderAI
# https://www.twitter.com/McoderAI
# https://www.linkedin.com/company/McoderAI
# https://mobirise.site/s
# https://mobirise.site/e
